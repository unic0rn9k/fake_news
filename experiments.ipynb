# %%
import pandas as pd

# %% [markdown]
# # Part 1: Data Processing (~1 page)
#
#     Task 1: Clean and process the FakeNewsCorpus sample data, using libraries like NLTK for text processing (tokenization, stopword removal, stemming).
#     Task 2: Explore the 995K FakeNewsCorpus subset. Make at least three interesting observations (e.g., outliers, patterns) and visualize key properties of the dataset.
#     Task 3: Apply your data preprocessing pipeline to the 995K subset.
#     Task 4: Split data into training, validation, and test sets (80%/10%/10%).

# %%
df = pd.read_csv("995,000_rows.csv")
df
# Out:
# /var/folders/89/bk15wb4x33g0_6ndpf2c8rqh0000gn/T/ipykernel_46229/1319880021.py:1: DtypeWarning: Columns (0,1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("995,000_rows.csv")
#        Unnamed: 0         id               domain        type  \
# 0             732  7444726.0   nationalreview.com   political
# 1            1348  6213642.0    beforeitsnews.com        fake
# 2            7119  3867639.0     dailycurrant.com      satire
# 3            1518  9560791.0          nytimes.com    reliable
# 4            9345  2059625.0  infiniteunknown.net  conspiracy
# ...           ...        ...                  ...         ...
# 994995       9376    1304673  21stcenturywire.com  conspiracy
# 994996       9625    7273484   nationalreview.com   political
# 994997       9561    3489380          thesaker.is     unknown
# 994998       4293    6315455        express.co.uk       rumor
# 994999       5020    2461199      sputniknews.com        bias
#
#                                                       url  \
# 0       http://www.nationalreview.com/node/152734/%E2%...
# 1       http://beforeitsnews.com/economy/2012/06/the-c...
# 2       http://dailycurrant.com/2016/01/18/man-awoken-...
# 3       https://query.nytimes.com/gst/fullpage.html?re...
# 4       http://www.infiniteunknown.net/2011/09/14/100-...
# ...                                                   ...
# 994995          http://21stcenturywire.com/tag/kony-2012/
# 994996  http://www.nationalreview.com/node/152734/%E2%...
# 994997  http://thesaker.is/china-and-russia-are-acquir...
# 994998  https://www.express.co.uk/pictures/sport/6708/...
# 994999  https://sputniknews.com/voiceofrussia/news/201...
#
#                                                   content  \
# 0       Plus one article on Google Plus\n\n(Thanks to ...
# 1       The Cost Of The Best Senate Banking Committee ...
# 2       Man Awoken From 27-Year Coma Commits Suicide A...
# 3       WHEN Julia Geist was asked to draw a picture o...
# 4       – 100 Compiled Studies on Vaccine Dangers (Act...
# ...                                                   ...
# 994995  By\n\n21WIRE + Intervention Watch | All we can...
# 994996  Plus one article on Google Plus\n\n(Thanks to ...
# 994997  China and Russia are Acquiring Gold, Dumping U...
# 994998  Liverpool have signed Sadio Mane from Southamp...
# 994999  CNN promoting coup in Venezuela - Maduro\n\nOn...
#
#                         scraped_at                 inserted_at  \
# 0       2017-11-27T01:14:42.983556  2018-02-08 19:18:34.468038
# 1         2017-11-27T01:14:08.7454  2018-02-08 19:18:34.468038
# 2       2017-11-27T01:14:21.395055  2018-02-07 23:39:33.852671
# 3       2018-02-11 00:46:42.632962  2018-02-11 00:14:20.346838
# 4       2017-11-10T11:18:44.524042  2018-02-07 23:39:33.852671
# ...                            ...                         ...
# 994995  2017-11-09T12:48:34.461199  2018-02-07 23:39:33.852671
# 994996  2017-11-27T01:14:42.983556  2018-02-08 19:18:34.468038
# 994997  2017-11-18T20:01:27.400599  2018-02-07 23:39:33.852671
# 994998  2017-11-27T01:14:33.570665  2018-02-08 19:18:34.468038
# 994999  2017-11-13T18:09:27.760857  2018-02-07 23:39:33.852671
#
#                         updated_at  \
# 0       2018-02-08 19:18:34.468066
# 1       2018-02-08 19:18:34.468066
# 2       2018-02-07 23:39:33.852696
# 3       2018-02-11 00:14:20.346871
# 4       2018-02-07 23:39:33.852696
# ...                            ...
# 994995  2018-02-07 23:39:33.852696
# 994996  2018-02-08 19:18:34.468066
# 994997  2018-02-07 23:39:33.852696
# 994998  2018-02-08 19:18:34.468066
# 994999  2018-02-07 23:39:33.852696
#
#                                                     title    authors  \
# 0                                      Iran News Round Up        NaN
# 1       The Cost Of The Best Senate Banking Committee ...        NaN
# 2       Man Awoken From 27-Year Coma Commits Suicide A...        NaN
# 3       Opening a Gateway for Girls to Enter the Compu...        NaN
# 4       100 Compiled Studies on Vaccine Dangers – Infi...        NaN
# ...                                                   ...        ...
# 994995                                 KONY 2012 Archives        NaN
# 994996                                 Iran News Round Up        NaN
# 994997  China and Russia are Acquiring Gold, Dumping U...  The Saker
# 994998        Twitter reacts as Liverpool sign Sadio Mane        NaN
# 994999           CNN promoting coup in Venezuela - Maduro        NaN
#
#         keywords                                      meta_keywords  \
# 0            NaN  ['National Review', 'National Review Online', ...
# 1            NaN                                               ['']
# 2            NaN                                               ['']
# 3            NaN  ['Computers and the Internet', 'Women and Girl...
# 4            NaN                                               ['']
# ...          ...                                                ...
# 994995       NaN                                               ['']
# 994996       NaN  ['National Review', 'National Review Online', ...
# 994997       NaN                                               ['']
# 994998       NaN                                               ['']
# 994999       NaN  ['CNN promoting coup in Venezuela - Maduro', '...
#
#                                          meta_description  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3       WHEN Julia Geist was asked to draw a picture o...
# 4                                                     NaN
# ...                                                   ...
# 994995                                                NaN
# 994996                                                NaN
# 994997                  A bird's eye view of the vineyard
# 994998  Express Sport brings you all the best tweets a...
# 994999  On Monday the President of Venezuela Nicolas M...
#
#                                                      tags  summary   source
# 0                                                     NaN      NaN      NaN
# 1                                                     NaN      NaN      NaN
# 2                                                     NaN      NaN      NaN
# 3                                                     NaN      NaN  nytimes
# 4       Lymphoma, Hepatitis B, Immune System, Health, ...      NaN      NaN
# ...                                                   ...      ...      ...
# 994995  Michelle Obama, Drones, Selfie, Uganda, smart ...      NaN      NaN
# 994996                                                NaN      NaN      NaN
# 994997                        Gold, Dollar, Russia, China      NaN      NaN
# 994998                                                NaN      NaN      NaN
# 994999                                                NaN      NaN      NaN
#
# [995000 rows x 17 columns]

# %% [markdown]
# # Part 2: Simple Logistic Regression Model (~1 page)
#
#     Task 0: Discuss how you grouped the fake/reliable labels and any limitations of your approach.
#     Task 1: Train a simple logistic regression model using the 10,000 most frequent words as features.
#     Task 2: Consider adding meta-data features and compare their effect on the model's performance.
#     Task 3: Incorporate extra reliable data scraped from Graded Exercise 2 and evaluate its impact on the model.

# %% [markdown]
# # Part 3: Advanced Model (~1 page)
#
#     Task 1: Develop a more complex model (e.g., Support Vector Machine, Naive Bayes, neural network) and explore more advanced features (e.g., TF-IDF, word embeddings).
#     Optional: Try training the model with the full 9GB FakeNewsCorpus (requires large storage and tools like 7z).

# %% [markdown]
# # Part 4: Evaluation (~1 page)
#
#     Task 1: Evaluate both your simple and advanced models on the FakeNewsCorpus test set and report performance (F-score, confusion matrix).
#     Task 2: Test your model on the LIAR dataset (cross-domain evaluation).
#     Task 3: Compare the results from the FakeNewsCorpus and LIAR evaluations.
